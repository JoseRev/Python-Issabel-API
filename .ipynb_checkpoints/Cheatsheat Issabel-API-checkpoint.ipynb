# %% [markdown]
# # <font color = 'Red'> Ejemplo de ISSABEL - API

# %%
import requests
import json

# %% [markdown]
# ### <font color = 'Blue'> Autenticar

# %%
Conmutador='http://192.168.1.64/pbxapi'                                   # Se modifca
payload={'username':'admin', 'password':'c3c0mr3d35'}                     # Se modifica
# Conmutador='http://localhost:2212/pbxapi'                               #SIP2 BURRO, mapeado con tunnel SSH
# payload={'username':'admin', 'password':'c3c0mr3d35'}                   #SIP2 BURRO, mapeado con tunnel SSH
r=requests.post(Conmutador+'/authenticate', verify=False, data=payload)   # No se modifica
token1=json.loads(r.text)                                                 # No se modifica
token1['access_token']                                                    # No se modifica
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2MTE1NTY0MzEsImV4cCI6MTYxMTU2MDAzMSwiZGF0YSI6eyJuYW1lIjoiYWRtaW4ifX0.TVJiYExeg0CU60JzGTAP5XPPHdQVxHtvD-VWTUOhjkA'

# %% [markdown]
# ### <font color = 'Blue'>Mostrar Troncales

# %%
r_trunk=requests.get(Conmutador+'/trunks', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
print(json.dumps(r_trunk.json(), indent=2))
# Out:
# {
#   "status": "success",
#   "results": [
#     {
#       "id": "69",
#       "name": "HMR_VII_RM",
#       "technology": "sip",
#       "channel_name": "a_HMR_VII",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.161.54",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "68",
#       "name": "12RCM_IAX_TRUNK",
#       "technology": "iax",
#       "channel_name": "12RCM",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "forcejitterbuffer": "yes",
#         "context": "from-internal",
#         "secret": "admin",
#         "host": "10.45.137.2",
#         "jitterbuffer": "yes",
#         "maxjitterbuffer": "1000",
#         "username": "A_cecom",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "67",
#       "name": "HMR_MAZATLAN",
#       "technology": "iax",
#       "channel_name": "HMR_MAZATLAN",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "context": "from-internal",
#         "host": "10.30.31.10",
#         "qualify": "yes",
#         "secret": "admin",
#         "trunk": "no",
#         "username": "A_cecom",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "66",
#       "name": "CME_108BI",
#       "technology": "sip",
#       "channel_name": "a_CME_108BI",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "host": "10.45.42.2",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "65",
#       "name": "44_ZM",
#       "technology": "iax",
#       "channel_name": "a_44zm",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "context": "from-internal",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no",
#         "trunk": "no",
#         "host": "10.7.162.163",
#         "username": "A_cecom",
#         "secret": "admin",
#         "type": "friend"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "64",
#       "name": "7_Z_M",
#       "technology": "iax",
#       "channel_name": "SEPTIMA",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "type": "friend",
#         "trunk": "no",
#         "qualify": "yes",
#         "host": "10.44.5.201",
#         "username": "A_cecom",
#         "disallow": "all",
#         "secret": "admin",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "63",
#       "name": "HMR_IV_RM",
#       "technology": "iax2",
#       "channel_name": "HMR_IV_RM",
#       "patterns": []
#     },
#     {
#       "id": "62",
#       "name": "EME",
#       "technology": "iax2",
#       "channel_name": "EME",
#       "patterns": []
#     },
#     {
#       "id": "61",
#       "name": "MEXSAT_SBC",
#       "technology": "sip",
#       "channel_name": "A_MEXSAT",
#       "patterns": [],
#       "peer": {
#         "allow": "all",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.175.6",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "60",
#       "name": "4BGDA_PM",
#       "technology": "iax",
#       "channel_name": "A_4BGDA_PM_1",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "maxjitterbuffer": "2000",
#         "host": "10.45.136.252",
#         "secret": "admin",
#         "username": "A_cecom",
#         "jitterbuffer": "yes",
#         "forcejitterbuffer": "yes",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "59",
#       "name": "82_BI_Y_GM_LAZARO",
#       "technology": "sip",
#       "channel_name": "GM_LAZARO_C",
#       "patterns": [],
#       "peer": {
#         "secret": "admin",
#         "type": "friend",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "username": "admin",
#         "host": "10.45.41.189",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "58",
#       "name": "BAM_11_EMATFA",
#       "technology": "sip",
#       "channel_name": "BAM11_EMATFA",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.38.228",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "57",
#       "name": "JFATURAS_IIIRM",
#       "technology": "sip",
#       "channel_name": "a_JEFATURAS",
#       "patterns": [],
#       "peer": {
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "username": "admin",
#         "allow": "g729",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.132.2"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "56",
#       "name": "a_CIATRANS_6",
#       "technology": "sip",
#       "channel_name": "a_CIATRANS6",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.1.6",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "",
#         "type": "friend",
#         "username": ""
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "55",
#       "name": "a_CIATRANS_7",
#       "technology": "sip",
#       "channel_name": "a_CIATRANS",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.1.7",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "",
#         "type": "friend",
#         "username": ""
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "54",
#       "name": "a_PSTN_CISCO",
#       "technology": "sip",
#       "channel_name": "a_PSTN_CISCO",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.70.8",
#         "disallow": "all",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "UCSc3c0m5DN",
#         "allow": "g729&ulaw",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "username": "UCSAplicacion"
#       },
#       "user": {
#         "disallow": "all",
#         "allow": "g729&ulaw",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.70.8",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "UCSc3c0m5DN",
#         "type": "friend",
#         "username": "UCSAplicacion"
#       },
#       "register": ""
#     },
#     {
#       "id": "53",
#       "name": "70BI_XICOTEPEC",
#       "technology": "sip",
#       "channel_name": "a_70BI_XICOTEPEC",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "username": "admin",
#         "qualify": "yes",
#         "secret": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "forcejitterbuffer": "yes",
#         "host": "10.45.136.3",
#         "insecure": "very",
#         "jitterbuffer": "yes",
#         "maxjitterbuffer": "1000",
#         "nat": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "52",
#       "name": "BAM_18",
#       "technology": "sip",
#       "channel_name": "a_BAM_18",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.42.132",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "51",
#       "name": "TRUNKING",
#       "technology": "sip",
#       "channel_name": "a_SIP_TRUNKING",
#       "patterns": [],
#       "peer": {
#         "allow": "ulaw&g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.60.9",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": {
#         "username": "admin",
#         "allow": "ulaw&g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.60.9",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend"
#       },
#       "register": ""
#     },
#     {
#       "id": "50",
#       "name": "4_ELN_MANTTO_I_RM",
#       "technology": "sip",
#       "channel_name": "a_4_ELN_MANTO",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.117.98",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "49",
#       "name": "CJR_CD_JUAREZ",
#       "technology": "iax",
#       "channel_name": "a_CJR_CD_JUAREZ",
#       "patterns": [],
#       "peer": {
#         "requirecalltoken": "no",
#         "allow": "g729",
#         "disallow": "all",
#         "qualify": "yes",
#         "trunk": "no",
#         "context": "from-internal",
#         "type": "friend",
#         "secret": "admin",
#         "username": "A_cecom",
#         "host": "10.7.130.130"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "48",
#       "name": "CJR_XRM",
#       "technology": "sip",
#       "channel_name": "d_CJR_XRM",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "host": "10.44.3.66",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "insecure": "very",
#         "nat": "no",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "47",
#       "name": "CJE_XII_RM_MPLS",
#       "technology": "sip",
#       "channel_name": "a_CJE_XII_RM_MPLS",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "username": "admin",
#         "host": "10.7.161.94",
#         "secret": "admin",
#         "nat": "no",
#         "qualify": "yes",
#         "insecure": "very",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833"
#       },
#       "user": {
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.161.94",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "allow": "g729"
#       },
#       "register": ""
#     },
#     {
#       "id": "46",
#       "name": "CJE_VI_RM_MPLS",
#       "technology": "sip",
#       "channel_name": "a_CJE_VI_RMMPLS",
#       "patterns": [],
#       "peer": {
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.2.68",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "45",
#       "name": "CJE_I_RM_2_BPM",
#       "technology": "sip",
#       "channel_name": "a_CJE_I_RM_2BPM",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "username": "admin",
#         "qualify": "yes",
#         "secret": "admin",
#         "nat": "no",
#         "host": "10.45.41.158",
#         "insecure": "very",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "44",
#       "name": "CJR_4_a_ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_4a_ZM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "type": "friend",
#         "username": "admin",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.161.126",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "43",
#       "name": "CJR_VI_RM_6RBR",
#       "technology": "iax2",
#       "channel_name": "CJR_VI_RM_6RBR",
#       "patterns": []
#     },
#     {
#       "id": "42",
#       "name": "CJR_I_RM",
#       "technology": "sip",
#       "channel_name": "a_SIP_CJR_I_RM",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "username": "admin",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.44.10.4",
#         "allow": "g729",
#         "canreinvite": "no",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend"
#       },
#       "user": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.10.4",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "register": ""
#     },
#     {
#       "id": "41",
#       "name": "CJR_VIIIRM",
#       "technology": "iax2",
#       "channel_name": "CJR_VIIIRM",
#       "patterns": []
#     },
#     {
#       "id": "40",
#       "name": "CJR_5ZM",
#       "technology": "sip",
#       "channel_name": "a_CECOM",
#       "patterns": [],
#       "peer": {
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "username": "admin",
#         "secret": "admin",
#         "type": "friend",
#         "host": "10.7.166.132",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "39",
#       "name": "CJR_3_ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_3ZM",
#       "patterns": [],
#       "peer": {
#         "host": "10.30.7.194",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "38",
#       "name": "HMR_VI_RM_TUXPAN",
#       "technology": "sip",
#       "channel_name": "HMR_VIRM",
#       "patterns": [],
#       "peer": {
#         "host": "10.45.34.98",
#         "context": "from-internal",
#         "disallow": "all",
#         "insecure": "very",
#         "nat": "no",
#         "dtmfmode": "rfc2833",
#         "allow": "g729",
#         "canreinvite": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "CECOM"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "37",
#       "name": "CJR_8ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_8ZM",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.30.10.66",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "36",
#       "name": "CG_43ZM",
#       "technology": "sip",
#       "channel_name": "a_CG_43ZM",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "allow": "g729",
#         "canreinvite": "no",
#         "host": "10.44.14.194",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "43ZM"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "35",
#       "name": "CJE_XIRM",
#       "technology": "sip",
#       "channel_name": "CJR_XIRM",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "allow": "g729",
#         "canreinvite": "no",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.30.5.96",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "34",
#       "name": "a_SIP_ESG",
#       "technology": "iax2",
#       "channel_name": "a_SIP_ESG",
#       "patterns": []
#     },
#     {
#       "id": "33",
#       "name": "CJR_IXRM",
#       "technology": "sip",
#       "channel_name": "a_CJR_IXRM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.7.82",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "A_cecom"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "32",
#       "name": "CJR_42ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_42ZM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.36.146",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "31",
#       "name": "CJR_10ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_10ZM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.33.127",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.33.227",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "register": ""
#     },
#     {
#       "id": "30",
#       "name": "CME_3ZM_NUEVO",
#       "technology": "sip",
#       "channel_name": "a_CME_3ZM",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "secret": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.203.0.254",
#         "insecure": "very",
#         "nat": "no",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "29",
#       "name": "HMR_VI",
#       "technology": "iax",
#       "channel_name": "A_hmr25zm",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "allow": "g729",
#         "qualify": "yes",
#         "username": "A_cecom",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "host": "10.7.130.5",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "28",
#       "name": "CME_JUICIOS",
#       "technology": "sip",
#       "channel_name": "a_CME_JUICIOS",
#       "patterns": [],
#       "peer": {
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.1.32"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "27",
#       "name": "3a_CINE",
#       "technology": "sip",
#       "channel_name": "3a_CINE",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.38.18",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "26",
#       "name": "JEAFTURAS VIII RM",
#       "technology": "sip",
#       "channel_name": "A_OAXACA",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "username": "admin",
#         "qualify": "yes",
#         "secret": "admin",
#         "nat": "no",
#         "host": "10.45.45.2",
#         "insecure": "invite",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "25",
#       "name": "UMCE_PINOTEPA",
#       "technology": "sip",
#       "channel_name": "d_UMCE_PINOTEPA",
#       "patterns": [],
#       "peer": {
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.42.41",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "24",
#       "name": "CPO_FZAS_ESP",
#       "technology": "iax",
#       "channel_name": "CPO_FZAS_ESP",
#       "patterns": [],
#       "peer": {
#         "forcejitterbuffer": "yes",
#         "requirecalltoken": "no",
#         "disallow": "all",
#         "allow": "g729",
#         "maxjitterbuffer": "1000",
#         "jitterbuffer": "yes",
#         "host": "10.45.5.146",
#         "username": "CECOM",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "23",
#       "name": "CENDI_6",
#       "technology": "iax2",
#       "channel_name": "CENDI_6",
#       "patterns": []
#     },
#     {
#       "id": "22",
#       "name": "2a_BPM",
#       "technology": "sip",
#       "channel_name": "a_2BPM",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "canreinvite": "no",
#         "insecure": "very",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "disallow": "all",
#         "nat": "no",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.41.147",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "21",
#       "name": "DIR_SVS",
#       "technology": "iax",
#       "channel_name": "DIR_SVS",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "host": "10.201.17.66",
#         "username": "CECOM_SDN",
#         "secret": "admin",
#         "type": "friend",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "20",
#       "name": "GAIN",
#       "technology": "sip",
#       "channel_name": "a_GAIN",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.200.6.5",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "19",
#       "name": "SIP_3",
#       "technology": "sip",
#       "channel_name": "A_SIP3",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.175.3",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "17",
#       "name": "EMTEFA",
#       "technology": "sip",
#       "channel_name": "EMTEFA",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.45.131.173",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "18",
#       "name": "UETAAM",
#       "technology": "sip",
#       "channel_name": "a_SIP_UETAM",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "invite",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.30.41.9"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "16",
#       "name": "GN_PEDREGAL_IAX",
#       "technology": "iax",
#       "channel_name": "GN_PEDREGAL_IAX",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "host": "10.44.26.10",
#         "username": "CECOM_IAX",
#         "context": "from-internal",
#         "secret": "admin",
#         "jitterbuffer": "yes",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no",
#         "maxjitterbuffer": "1000",
#         "forcejitterbuffer": "yes"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "14",
#       "name": "HMR_X_RM",
#       "technology": "iax2",
#       "channel_name": "HMR_X_RM",
#       "patterns": []
#     },
#     {
#       "id": "15",
#       "name": "HMZ_34ZM",
#       "technology": "sip",
#       "channel_name": "A_34ZM",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.45.145.34",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "12",
#       "name": "RASE",
#       "technology": "sip",
#       "channel_name": "a_SIP_RASE",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.45.35.4",
#         "dtmfmode": "rfc2833",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "13",
#       "name": "HMZ_SMJ",
#       "technology": "sip",
#       "channel_name": "HMZ_SMJ",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729",
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.237.20.31",
#         "dtmfmode": "rfc2833",
#         "disallow": "all"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "11",
#       "name": "HMZ_24ZM",
#       "technology": "iax",
#       "channel_name": "HMZ_24ZM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "disallow": "all",
#         "host": "10.45.33.19",
#         "username": "CECOM_IAX",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "requirecalltoken": "no",
#         "jitterbuffer": "yes",
#         "forcejitterbuffer": "yes",
#         "maxjitterbuffer": "1000"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "10",
#       "name": "7_BIC",
#       "technology": "sip",
#       "channel_name": "a_SIP_7_BIC",
#       "patterns": [],
#       "peer": {
#         "username": "admin",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "invite",
#         "host": "10.45.135.226",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "9",
#       "name": "A_SIP5",
#       "technology": "sip",
#       "channel_name": "a_SIP5",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "secret": "admin",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.175.5",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "username": "admin",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "8",
#       "name": "CIAM",
#       "technology": "sip",
#       "channel_name": "a_CIAM",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "nat": "no",
#         "context": "from-internal",
#         "insecure": "very",
#         "host": "10.45.130.163",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "6",
#       "name": "HMR_XII_RM",
#       "technology": "iax2",
#       "channel_name": "HMR_XII_RM",
#       "patterns": []
#     },
#     {
#       "id": "7",
#       "name": "CJR_V_RM_11_ZM",
#       "technology": "sip",
#       "channel_name": "a_CJR_V_RM_11_ZM",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "very",
#         "host": "10.7.161.182",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "5",
#       "name": "CJE_V_RM_SKY_EDGE",
#       "technology": "sip",
#       "channel_name": "a_CJE_V_RM",
#       "patterns": [],
#       "peer": {
#         "host": "10.45.13.185",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.13.185",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "register": ""
#     },
#     {
#       "id": "4",
#       "name": "a_BANDA_Ku",
#       "technology": "sip",
#       "channel_name": "A_Ku",
#       "patterns": [],
#       "peer": {
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "allow": "ulaw",
#         "dtmfmode": "rfc2833",
#         "host": "172.20.1.50",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "s3c0msdn",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": {
#         "allow": "ulaw",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "host": "172.20.1.50",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "s3c0msdn",
#         "type": "friend",
#         "username": "admin"
#       },
#       "register": ""
#     },
#     {
#       "id": "3",
#       "name": "a_70_9",
#       "technology": "sip",
#       "channel_name": "A_70_9",
#       "patterns": [],
#       "peer": {
#         "dtmfmode": "rfc2833",
#         "host": "10.201.70.9",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "UCSAplicacion",
#         "disallow": "all",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "type": "friend",
#         "username": "UCSAplicacion"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "2",
#       "name": "DN14",
#       "technology": "sip",
#       "channel_name": "A_SIP_DN14",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.169.5",
#         "insecure": "invite",
#         "nat": "no",
#         "qualify": "yes",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "1",
#       "name": "a_70_8",
#       "technology": "sip",
#       "channel_name": "A_70_8",
#       "patterns": [],
#       "peer": {
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "UCSc3c0m5DN",
#         "type": "friend",
#         "username": "UCSAplicacion",
#         "host": "10.201.70.8",
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729"
#       },
#       "user": {
#         "dtmfmode": "rfc2833",
#         "disallow": "all",
#         "username": "UCSAplicacion",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "allow": "g729",
#         "host": "10.201.70.8",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "UCSc3c0m5DN",
#         "type": "friend",
#         "user": "UCSAplicacion"
#       },
#       "register": ""
#     },
#     {
#       "id": "70",
#       "name": "CRIADERO_MIL_GANADO",
#       "technology": "sip",
#       "channel_name": "CMG",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.134.148",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "71",
#       "name": "HMR_35ZM",
#       "technology": "sip",
#       "channel_name": "HMR_35ZM",
#       "patterns": [],
#       "peer": {
#         "nat": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "username": "HMR_35ZM",
#         "secret": "admin",
#         "host": "10.7.162.100",
#         "insecure": "very",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "type": "friend"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "72",
#       "name": "101_BI",
#       "technology": "iax",
#       "channel_name": "101_BI",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "host": "10.45.135.146",
#         "username": "CECOM_SDN",
#         "requirecalltoken": "no",
#         "jitterbuffer": "yes",
#         "disallow": "all",
#         "secret": "admin",
#         "forcejitterbuffer": "yes",
#         "maxjitterbuffer": "1000"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "73",
#       "name": "DIR_ARMAS",
#       "technology": "iax2",
#       "channel_name": "DIR_ARMAS",
#       "patterns": []
#     },
#     {
#       "id": "74",
#       "name": "CG_27ZM",
#       "technology": "iax",
#       "channel_name": "27ZM_IAX2",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "requirecalltoken": "no",
#         "disallow": "all",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "host": "10.44.10.194",
#         "username": "A_cecom",
#         "secret": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "75",
#       "name": "JFTAS_XIIRM",
#       "technology": "iax",
#       "channel_name": "JFTAS_XIIRM",
#       "patterns": [],
#       "peer": {
#         "forcejitterbuffer": "yes",
#         "jitterbuffer": "yes",
#         "disallow": "all",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "host": "10.45.135.179",
#         "maxjitterbuffer": "1000",
#         "username": "CECOM_SDN",
#         "secret": "admin",
#         "type": "friend",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "76",
#       "name": "A_PUNTO_4",
#       "technology": "sip",
#       "channel_name": "A_PUNTO_4",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.175.4",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "77",
#       "name": "CMI",
#       "technology": "sip",
#       "channel_name": "CME_CMI",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.240.200",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "78",
#       "name": "CENDI_3",
#       "technology": "sip",
#       "channel_name": "CENDI_3",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.201.0.56",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "79",
#       "name": "46_ZM",
#       "technology": "iax",
#       "channel_name": "A_cecom",
#       "patterns": [],
#       "peer": {
#         "username": "A_46ZM",
#         "host": "10.7.162.195",
#         "requirecalltoken": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729&ullaw",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "80",
#       "name": "CJ_IXTEPEC",
#       "technology": "iax",
#       "channel_name": "a_IXTEPEC",
#       "patterns": [],
#       "peer": {
#         "trunk": "no",
#         "type": "friend",
#         "username": "A_cecom",
#         "secret": "admin",
#         "host": "10.45.11.106",
#         "context": "from-internal",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "81",
#       "name": "CENDI_4",
#       "technology": "sip",
#       "channel_name": "CENDI_4",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.21.194",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "CECOM"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "82",
#       "name": "ESC_MIL_SGTOS",
#       "technology": "iax",
#       "channel_name": "ESC_MIL_SGTOS",
#       "patterns": [],
#       "peer": {
#         "host": "10.45.136.66",
#         "jitterbuffer": "yes",
#         "forcejitterbuffer": "yes",
#         "disallow": "all",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "requirecalltoken": "no",
#         "allow": "g729",
#         "maxjitterbuffer": "2000",
#         "username": "A_cecom",
#         "secret": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "83",
#       "name": "CJ_VRM_13ZM",
#       "technology": "iax",
#       "channel_name": "A_CJ_VRM_13ZM",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "username": "A_cecom",
#         "secret": "admin",
#         "type": "friend",
#         "trunk": "no",
#         "host": "10.44.7.66",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "84",
#       "name": "CJ_MORELIA",
#       "technology": "iax",
#       "channel_name": "a_cj_morelia",
#       "patterns": [],
#       "peer": {
#         "trunk": "no",
#         "type": "friend",
#         "qualify": "yes",
#         "context": "from-internal",
#         "host": "10.45.10.99",
#         "username": "A_cecom",
#         "secret": "admin",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "85",
#       "name": "CJ_VICTORIA",
#       "technology": "iax",
#       "channel_name": "CJ_VICTORIA",
#       "patterns": [],
#       "peer": {
#         "type": "friend",
#         "context": "from-internal",
#         "qualify": "yes",
#         "host": "10.45.3.25",
#         "allow": "g729",
#         "username": "A_cecom",
#         "secret": "admin",
#         "requirecalltoken": "no",
#         "disallow": "all",
#         "trunk": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "86",
#       "name": "cj_culiacan",
#       "technology": "iax",
#       "channel_name": "cj_culiacan",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "allow": "g729",
#         "username": "A_cecom",
#         "requirecalltoken": "no",
#         "trunk": "no",
#         "qualify": "yes",
#         "host": "10.44.6.66",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "87",
#       "name": "CJR_19ZM",
#       "technology": "iax",
#       "channel_name": "a_cjr_19zm",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "maxjitterbuffer": "1000",
#         "host": "10.45.146.150",
#         "allow": "g729",
#         "trunk": "no",
#         "username": "A_cecom",
#         "secret": "admin",
#         "type": "friend",
#         "requirecalltoken": "no",
#         "jitterbuffer": "yes",
#         "forcejitterbuffer": "yes",
#         "qualify": "yes",
#         "disallow": "all"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "88",
#       "name": "CJR_33ZM_CAMP",
#       "technology": "iax",
#       "channel_name": "cj_33_ZONA_M",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "host": "10.44.12.66",
#         "username": "A_cecom",
#         "requirecalltoken": "no",
#         "qualify": "yes",
#         "type": "friend",
#         "trunk": "no",
#         "context": "from-internal",
#         "secret": "admin",
#         "disallow": "all"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "89",
#       "name": "cj_IX_RM_CHILPA",
#       "technology": "iax",
#       "channel_name": "cj_IX_RM_CHILPA",
#       "patterns": [],
#       "peer": {
#         "maxjitterbuffer": "1000",
#         "type": "friend",
#         "username": "A_cecom",
#         "trunk": "no",
#         "jitterbuffer": "yes",
#         "forcejitterbuffer": "yes",
#         "secret": "admin",
#         "context": "from-internal",
#         "host": "10.45.38.68",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "90",
#       "name": "CME_VILLAH",
#       "technology": "sip",
#       "channel_name": "a_CME_VILLAH",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.39.130",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "91",
#       "name": "79_BI_TECALITLAN",
#       "technology": "iax",
#       "channel_name": "BI_Tecalitlan",
#       "patterns": [],
#       "peer": {
#         "host": "10.45.44.195",
#         "type": "friend",
#         "context": "from-internal",
#         "secret": "admin",
#         "username": "A_cecom",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "allow": "g729",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "92",
#       "name": "EMAAYS",
#       "technology": "sip",
#       "channel_name": "EMAAYS",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.21.66",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "93",
#       "name": "CME_JUZG_IIRM",
#       "technology": "sip",
#       "channel_name": "CME_JUZ_IIRM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.202.51.2",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "94",
#       "name": "HMR_XIRM_TORREON",
#       "technology": "sip",
#       "channel_name": "HMR_TORREON",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.16.2",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "95",
#       "name": "5 BIC",
#       "technology": "sip",
#       "channel_name": "5_BIC",
#       "patterns": [],
#       "peer": {
#         "allow": "g729&ulaw&alaw",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.34.114",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "96",
#       "name": "CENDI_APODACA",
#       "technology": "iax",
#       "channel_name": "A_CENDI_Apodaca",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "type": "friend",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "host": "10.44.25.194",
#         "username": "A_cecom",
#         "secret": "admin",
#         "requirecalltoken": "no",
#         "context": "from-internal"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "97",
#       "name": "HOSPITALMUJER",
#       "technology": "iax2",
#       "channel_name": "HOSPITALMUJER",
#       "patterns": []
#     },
#     {
#       "id": "98",
#       "name": "JRS_IV_RM",
#       "technology": "iax",
#       "channel_name": "JRSIVRM",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "host": "10.207.0.10",
#         "username": "CECOM",
#         "secret": "admin",
#         "disallow": "all",
#         "allow": "g729&ulaw&alaw",
#         "requirecalltoken": "no"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "99",
#       "name": "CRI",
#       "technology": "sip",
#       "channel_name": "CRI",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.7.170.125",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "100",
#       "name": "HMZ_1A",
#       "technology": "sip",
#       "channel_name": "HMZ_1A",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.30.102.116",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "101",
#       "name": "BLT",
#       "technology": "iax2",
#       "channel_name": "BLT",
#       "patterns": []
#     },
#     {
#       "id": "102",
#       "name": "HOSP_CTRAL_MIL",
#       "technology": "sip",
#       "channel_name": "a_HCM",
#       "patterns": [],
#       "peer": {
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.200.20.3",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "type": "friend",
#         "username": "admin",
#         "secret": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "103",
#       "name": "GM_PIEDRASN",
#       "technology": "iax",
#       "channel_name": "GM_PIEDRASN",
#       "patterns": [],
#       "peer": {
#         "qualify": "yes",
#         "requirecalltoken": "no",
#         "context": "from-internal",
#         "host": "10.45.15.134",
#         "username": "CECOM_SDN",
#         "secret": "admin",
#         "type": "friend",
#         "trunk": "no",
#         "disallow": "all",
#         "allow": "g729"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "104",
#       "name": "UMCE_40ZM",
#       "technology": "iax",
#       "channel_name": "UMCE_40ZM",
#       "patterns": [],
#       "peer": {
#         "disallow": "all",
#         "host": "10.44.14.50",
#         "username": "A_CECOM",
#         "type": "friend",
#         "secret": "admin",
#         "qualify": "yes",
#         "nat": "no",
#         "insecure": "very",
#         "dtmfmode": "rfc2833",
#         "context": "from-internal",
#         "canreinvite": "no",
#         "forcejitterbuffer": "yes",
#         "allow": "g729",
#         "jitterbuffer": "yes",
#         "maxjitterbuffer": "1000"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "105",
#       "name": "UMCE_8ZM",
#       "technology": "iax2",
#       "channel_name": "UMCE_8ZM",
#       "patterns": []
#     },
#     {
#       "id": "106",
#       "name": "6_BPM",
#       "technology": "sip",
#       "channel_name": "6_BPM",
#       "patterns": [],
#       "peer": {
#         "host": "10.201.70.87",
#         "insecure": "invite",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "username": "admin",
#         "type": "friend",
#         "allow": "g729",
#         "canreinvite": "no",
#         "context": "from-internal"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "107",
#       "name": "CME_PENAS_ESCOBEDO",
#       "technology": "sip",
#       "channel_name": "CME_PENAS_ESCOBEDO",
#       "patterns": [],
#       "peer": {
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "canreinvite": "no",
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.37.82",
#         "insecure": "very",
#         "allow": "g729&ulaw&alaw",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "108",
#       "name": "UMCE_TAPACHULA",
#       "technology": "sip",
#       "channel_name": "umce_tapachula",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.45.35.83",
#         "insecure": "invite",
#         "nat": "no",
#         "qualify": "yes",
#         "canreinvite": "no",
#         "allow": "g729",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "109",
#       "name": "GN_PEDREGAL_SIP",
#       "technology": "sip",
#       "channel_name": "GN_PEDREGAL_SIP",
#       "patterns": [],
#       "peer": {
#         "context": "from-internal",
#         "allow": "g729",
#         "canreinvite": "no",
#         "disallow": "all",
#         "dtmfmode": "rfc2833",
#         "host": "10.44.26.10",
#         "insecure": "very",
#         "nat": "no",
#         "qualify": "yes",
#         "secret": "admin",
#         "type": "friend",
#         "username": "admin"
#       },
#       "user": [],
#       "register": ""
#     },
#     {
#       "id": "110",
#       "name": "CRI_IAX",
#       "technology": "iax",
#       "channel_name": "CRI_IAX",
#       "patterns": [],
#       "peer": {
#         "forcejitterbuffer": "yes",
#         "requirecalltoken": "no",
#         "jitterbuffer": "yes",
#         "allow": "g729",
#         "host": "10.7.170.125",
#         "username": "a_CECOM_IAX",
#         "secret": "admin",
#         "type": "friend",
#         "context": "from-internal",
#         "trunk": "no",
#         "qualify": "yes",
#         "disallow": "all",
#         "maxjitterbuffer": "1000"
#       },
#       "user": [],
#       "register": ""
#     }
#   ]
# }
# 110

# %% [markdown]
# ### <font color = 'Blue'>Mostrar Extensiones

# %%
r_ext=requests.get(Conmutador+'/extensions', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
print(json.dumps(r_ext.json(), indent=2))
# Out:
# {
#   "status": "success",
#   "results": [
#     {
#       "dial": "SIP/1000",
#       "secret": "1000tr",
#       "context": "from-internal",
#       "extension": "1000",
#       "name": "RESERVADA",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1001",
#       "secret": "1001tr",
#       "context": "from-internal",
#       "extension": "1001",
#       "name": "MESA DE ENTRADA CECOM",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1143",
#       "secret": "1143tr",
#       "context": "from-internal",
#       "extension": "1143",
#       "name": "1143",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1144",
#       "secret": "1144tr",
#       "context": "from-internal",
#       "extension": "1144",
#       "name": "1144",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1213",
#       "secret": "1213tr",
#       "context": "from-internal",
#       "extension": "1213",
#       "name": "RESIDENCIA",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1218",
#       "secret": "1218tr",
#       "context": "from-internal",
#       "extension": "1218",
#       "name": "1218",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1280",
#       "secret": "1280ce",
#       "context": "from-internal",
#       "extension": "1280",
#       "name": "CECOM ALMACENES 1280",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1281",
#       "secret": "1281tr",
#       "context": "from-internal",
#       "extension": "1281",
#       "name": "1 RCM CMCIA 1281",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1282",
#       "secret": "1282tr",
#       "context": "from-internal",
#       "extension": "1282",
#       "name": "1 RCM SIIO 1282",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1283",
#       "secret": "1283tr",
#       "context": "from-internal",
#       "extension": "1283",
#       "name": "1 RCM PAGADURIA 1283",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     },
#     {
#       "dial": "SIP/1284",
#       "secret": "1284tr",
#       "context": "from-internal",
#       "extension": "1284",
#       "name": "1 RCM PTN INF 1284",
#       "tech": "sip",
#       "voicemail": [],
#       "followme": [],
#       "dictation": []
#     }
#   ]
# }

# %% [markdown]
# ### <font color = 'Blue'>Mostrar Rutas Salida

# %%
r_out=requests.get(Conmutador+'/outboundroutes', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
print(json.dumps(r_out.json(), indent=2))
# Out:
# {
#   "status": "success",
#   "results": [
#     {
#       "id": "3",
#       "name": "7_BIC",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "102[4-6]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "11",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "2",
#       "name": "ESC_SUP_GRRA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "100[5-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "12",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "4",
#       "name": "RASE",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "102[7-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "14",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "75",
#       "name": "44_Z_M",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[2-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2444",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "64",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "107",
#       "name": "RTM_CISCO",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "14[6-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[0-1]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[5-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "22[0-8]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "23XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "240[1-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "244[1-3]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "244[5-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "246[7-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2470",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "24[1-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "25XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "265X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2660",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "266[1-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "26[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "270[4-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "27[1-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2[0-1]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2[8-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3124",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3519",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3XXX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "5[3-4]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "68[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "69XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "6[5-7]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "701[0-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "701[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "89XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "95[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "95[5-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "968[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "988X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[0-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[12]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[7-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "999[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "1",
#           "sequence": "0"
#         },
#         {
#           "trunk_id": "3",
#           "sequence": "1"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "108",
#       "name": "SIP_5",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1[5-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "6932",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "7996",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "90[4-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "94XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "954X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "9[6-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "10",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "9",
#       "name": "DN14",
#       "outbound_callerid": "SIP_DN14",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "93XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "2",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "10",
#       "name": "PSTN",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "06[1-9]XXXXXXXXX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "50",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "85",
#       "name": "HMR_IV_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1096",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "68",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "12",
#       "name": "HMR_XIIRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "100[2-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "6",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "13",
#       "name": "HMZ_SMJ",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1017",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "15",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "14",
#       "name": "HOSP_24_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "101[3-6]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "13",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "16",
#       "name": "HOSP_34ZM",
#       "outbound_callerid": "SIP_34ZM",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "102[0-2]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "17",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "25",
#       "name": "CENDI_6",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "104[3-5]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "65",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "19",
#       "name": "UETA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "103[5-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "19",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "20",
#       "name": "HOSP_25ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1039",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "104[0-1]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "31",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "21",
#       "name": "GAIN",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "801[1-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "21",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "23",
#       "name": "2a_BPM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "104[6-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "23",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "55",
#       "name": "CJE_VRM_SEII",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1080",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "8",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "54",
#       "name": "CJR_V_RM_11_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1079",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "5",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "30",
#       "name": "UMCE_PINOTEPA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1055",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "26",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "207",
#       "name": "UMCE_TAPACHULA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1056",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "45",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "33",
#       "name": "3a_CINE",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "960[6-7]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "29",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "35",
#       "name": "EMTEFA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1059",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "61",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "37",
#       "name": "CJR_10ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1060",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "33",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "38",
#       "name": "CJR_42ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1062",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "35",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "39",
#       "name": "CJR_IXRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1063",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "34",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "198",
#       "name": "JEFATURAS_XIIRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "109[4-5]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "66",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "41",
#       "name": "CJE_XIRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1065",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "37",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "42",
#       "name": "CG_43ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1614",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1741",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1763",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "228[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[01]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "38",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "43",
#       "name": "CJR_8ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1066",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "39",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "165",
#       "name": "HOSP_CTRL_CISCO",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2660",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "1",
#           "sequence": "0"
#         },
#         {
#           "trunk_id": "3",
#           "sequence": "1"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "45",
#       "name": "CJR_3a_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1068",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "41",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "46",
#       "name": "CJR_5ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1077",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "42",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "48",
#       "name": "CJR_VIII_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1074",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "43",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "49",
#       "name": "CJR_I_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1075",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "44",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "50",
#       "name": "CJR_VIRM_6RBR",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1072",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "27",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "51",
#       "name": "CJR_4a_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1073",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "46",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "52",
#       "name": "CJE_I_RM_2_BPM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1078",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "47",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "53",
#       "name": "CJE_VI_RM_MPLS",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1071",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "48",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "56",
#       "name": "CJE_XII_RM_MPLS",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1070",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "22",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "57",
#       "name": "CJR_XRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1083",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "49",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "58",
#       "name": "CJR_GN_JUAREZ",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1081",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "56",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "59",
#       "name": "4oELN_MNTO_IRM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1076",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "51",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "60",
#       "name": "BAM_11_EMATFA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1084",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "53",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "61",
#       "name": "70BI_XICOTEPEC",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1085",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "54",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "63",
#       "name": "A_CIATRANS",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "26[7-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3XXX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "4035",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "4XXX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "5[0-2]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "5[5-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "6[0-4]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "8854",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "88XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "8[0-4]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "57",
#           "sequence": "0"
#         },
#         {
#           "trunk_id": "58",
#           "sequence": "1"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "64",
#       "name": "JFRAS_III_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1091",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "59",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "68",
#       "name": "TRONCALIZADO",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "8959",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "52",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "69",
#       "name": "BAM_18",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "103[0-1]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "55",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "70",
#       "name": "82BI_Y_GM_LAZAR_C",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "108[6-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1090",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "60",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "71",
#       "name": "4_BGDA_PM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "109[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "62",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "204",
#       "name": "6_BgdaPM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1143",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "18",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "79",
#       "name": "7_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "214[4-7]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "67",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "113",
#       "name": "46_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2549",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "255[0-2]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "85",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "128",
#       "name": "79_BI_TECALITLAN",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "111[3-5]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "98",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "115",
#       "name": "CJ_IXTEPEC",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1042",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "86",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "199",
#       "name": "GM_PIEDRASN",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "110[5-6]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "70",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "200",
#       "name": "HMR_X_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "264[0-2]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "16",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "95",
#       "name": "HOSP_35_ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "110[0-1]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "76",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "103",
#       "name": "CG_27ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "222[4-7]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "79",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "90",
#       "name": "A_HMR_MAZATLAN",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "259[6-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "71",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "91",
#       "name": "HMR_VII_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "264[4-5]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "7",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "92",
#       "name": "12RCM_PIED_NEG",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "129[2-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "72",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "93",
#       "name": "CMG_STA_GERT",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "112[6-7]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "74",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "151",
#       "name": "101_BI",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "112[2-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "30",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "97",
#       "name": "108BI",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "958[3-5]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "69",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "112",
#       "name": "CENDI_3",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2715",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "8953",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "84",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "111",
#       "name": "JEFATURAS_VIII_RM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "110[7-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "83",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "116",
#       "name": "CENDI_4",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2365",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
# ...
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "25",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "188",
#       "name": "CPO_FZAS_ESP",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1052",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "40",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "195",
#       "name": "UMCE_8ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1057",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "24",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "162",
#       "name": "HOSP_CTRL_MIL",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3111",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3121",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3124",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3196",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3197",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3239",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3273",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3291",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3390",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3439",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3464",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3466",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3500",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3516",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3733",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3735",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "1",
#           "sequence": "0"
#         },
#         {
#           "trunk_id": "3",
#           "sequence": "1"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "194",
#       "name": "UMCE_40ZM",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1058",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "28",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "206",
#       "name": "GN_TORRE_PEDREGAL",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "131[2-6]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "106",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "208",
#       "name": "7_BIC",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "102[4-6]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "11",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "209",
#       "name": "ESC_SUP_GRRA",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "100[5-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "12",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "210",
#       "name": "RASE",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "102[7-8]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "14",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "211",
#       "name": "44_Z_M",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[2-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2444",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "64",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "212",
#       "name": "RTM_CISCO",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "14[6-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[0-1]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "229[5-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "22[0-8]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "23XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "240[1-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "244[1-3]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "244[5-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "246[7-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2470",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "24[1-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "25XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "265X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2660",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "266[1-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "26[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "270[4-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "27[1-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2[0-1]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "2[8-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3124",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3519",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "3XXX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "5[3-4]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "68[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "69XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "6[5-7]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "701[0-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "701[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "89XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "95[0-3]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "95[5-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "968[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "988X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[0-4]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[12]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "989[7-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "999[8-9]",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "1",
#           "sequence": "0"
#         },
#         {
#           "trunk_id": "3",
#           "sequence": "1"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     },
#     {
#       "id": "213",
#       "name": "SIP_5",
#       "outbound_callerid": "",
#       "music_on_hold_class": "default",
#       "destination_if_congestion": "",
#       "time_group_id": "0",
#       "patterns": [
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "1[5-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "6932",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "7996",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "90[4-9]X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "94XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "954X",
#           "match_callerid": "",
#           "prepend_digits": ""
#         },
#         {
#           "match_pattern_prefix": "",
#           "match_pattern_pass": "9[6-9]XX",
#           "match_callerid": "",
#           "prepend_digits": ""
#         }
#       ],
#       "trunks": [
#         {
#           "trunk_id": "10",
#           "sequence": "0"
#         }
#       ],
#       "call_recording": "",
#       "pinsets_id": "0"
#     }
#   ]
# }

# %% [markdown]
# ### <font color = 'Blue'> Mostrar Rutas de Entrada

# %%
r_in=requests.get(Conmutador+'/inboundroutes', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
print(json.dumps(r_in.json(), indent=2))
# Out:
# {
#   "status": "success",
#   "results": []
# }

# %% [markdown]
# ### <font color = 'Blue'> Mostrar Grabaciones

# %%
r_rec=requests.get(Conmutador+'/recordings', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
print(json.dumps(r_rec.json(), indent=2))
# Out:
# {
#   "status": "success",
#   "results": [
#     {
#       "id": "1",
#       "name": "__invalid",
#       "audiofiles": [
#         {
#           "filename": "install done",
#           "sequence": "0"
#         }
#       ]
#     },
#     {
#       "id": "4",
#       "name": "MENUSIP",
#       "audiofiles": [
#         {
#           "filename": "custom/MENUSIP",
#           "sequence": "0"
#         }
#       ]
#     },
#     {
#       "id": "20",
#       "name": "UNO",
#       "audiofiles": [
#         {
#           "filename": "custom/UNO",
#           "sequence": "0"
#         }
#       ]
#     },
#     {
#       "id": "16",
#       "name": "IVRSIP",
#       "audiofiles": [
#         {
#           "filename": "custom/IVRSIP",
#           "sequence": "0"
#         }
#       ]
#     },
#     {
#       "id": "18",
#       "name": "IVR_SSC",
#       "audiofiles": [
#         {
#           "filename": "custom/IVR_SSC",
#           "sequence": "0"
#         }
#       ]
#     },
#     {
#       "id": "19",
#       "name": "IVR_SSC_1",
#       "audiofiles": [
#         {
#           "filename": "custom/IVR_SSC_1",
#           "sequence": "0"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ### <font color = 'Blue'> Agregar Extension

# %%
extension="""
{
    "name": "203",
    "secret": "203toga",
    "context": "from-internal",
    "extension": "203",
    "tech": "sip",
    "voicemail": "novm"
}
"""
r=requests.put(Conmutador+'/extensions/203', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']}, data=extension)
r.text

# %% [markdown]
# ### <font color = 'Blue'> Agregar Troncal

# %%
troncal1={
        "id": '4',
        "name": "Tapia",
        "technology": "sip",
        "channel_name": "Alcarazasasas",
        "patterns": [{
            "match_pattern_prefix": "",
            "match_pattern_pass": "2X46",
            "prepend_digits": "",
            "seq": "1"
        }],
        "peer": {
            "host": "192.168.1.138",
            "username": "rusos",
            "secret": "12345",
            "type": "peer"
            
        },
        "user": [],
        "register": ""
}


print(type(troncal1))
print(type(json.dumps(troncal1)))     #json.dumps() returns string (json.object)
                                      #json.loads() returns python dict
r=requests.post(Conmutador+'/trunks/', verify=False, headers= {"content-type": "application/json", "Authorization": "Bearer " + token1['access_token']}, data=json.dumps(troncal1))
r
# Out:
# <class 'dict'>
# <class 'str'>
# <Response [201]>

# %% [markdown]
# ### <font color = 'Blue'> Borrar Extension </font> <font color = 'Red'> (Warning)

# %%
r=requests.delete(Conmutador+'/extensions/1159', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
r.text
# Out:
# '{"status": "expired"}'

# %% [markdown]
# ### <font color = 'Blue'> Borrar Grupo de Extensiones </font> <font color = 'Red'> (Warning)

# %%
total=len(r_ext.json()['results'])
for num, extension in enumerate( r_ext.json()['results']):
    r_ext=requests.delete(Conmutador+'/extensions/'+ extension['extension'], verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
    print (f"{num+1} de {total}", extension['extension'], str(r_ext) +" "+ str(r_ext.reason))    # Se repite la instrucion r_ext???
    #if num == 5:
    #    break
# Out:
# 0 de 11 1000 <Response [200]> OK
# 1 de 11 1001 <Response [200]> OK
# 2 de 11 1143 <Response [200]> OK
# 3 de 11 1144 <Response [200]> OK
# 4 de 11 1213 <Response [200]> OK
# 5 de 11 1218 <Response [200]> OK
# 6 de 11 1280 <Response [200]> OK
# 7 de 11 1281 <Response [200]> OK
# 8 de 11 1282 <Response [200]> OK
# 9 de 11 1283 <Response [200]> OK
# 10 de 11 1284 <Response [200]> OK

# %% [markdown]
# ### <font color = 'Blue'> Borrar Troncal </font> <font color = 'Red'> (Warning)

# %%
r=requests.delete(Conmutador+'/trunks/3', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
r.json
# Out:
# <bound method Response.json of <Response [200]>>

# %% [markdown]
# ### <font color = 'Blue'> Borrar Grupo de Troncales </font> <font color = 'Red'> (Warning)

# %%
total=len(r_trunk.json()['results'])
for index,trunk in enumerate(r_trunk.json()['results']):
    r_trunk_del=requests.delete(Conmutador+'/trunks/'+ trunk['id'], verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
    print (f"{index+1} de {total}", f"{r_trunk_del} {r_trunk_del.reason}")
# Out:
# 0 de 19 <Response [200]> OK
# 1 de 19 <Response [200]> OK
# 2 de 19 <Response [200]> OK
# 3 de 19 <Response [200]> OK
# 4 de 19 <Response [200]> OK
# 5 de 19 <Response [200]> OK
# 6 de 19 <Response [200]> OK
# 7 de 19 <Response [200]> OK
# 8 de 19 <Response [200]> OK
# 9 de 19 <Response [200]> OK
# 10 de 19 <Response [200]> OK
# 11 de 19 <Response [200]> OK
# 12 de 19 <Response [200]> OK
# 13 de 19 <Response [200]> OK
# 14 de 19 <Response [200]> OK
# 15 de 19 <Response [200]> OK
# 16 de 19 <Response [200]> OK
# 17 de 19 <Response [200]> OK
# 18 de 19 <Response [200]> OK

# %% [markdown]
# ### <font color = 'Blue'> Borrar Ruta Salida </font> <font color = 'Red'> (Warning)

# %%
r_out_del=requests.delete(Conmutador+'/outboundroutes/'+ ruta['id'], verify=False, headers= {"Authorization": "Bearer " + token2['access_token']})
r_out_del.json()

# %% [markdown]
# ### <font color = 'Blue'> Borrar Grupo de Rutas Salida </font> <font color = 'Red'> (Warning)

# %%
total=len(r_out.json()['results'])
for index,ruta in enumerate(r_out.json()['results']):
    r_out_del=requests.delete(Conmutador+'/outboundroutes/'+ ruta['id'], verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
    print (f"{index+1} de {total}", f"{r_out_del} {r_out_del.reason}")
# Out:
# 0 de 105 <Response [200]> OK
# 1 de 105 <Response [200]> OK
# 2 de 105 <Response [200]> OK
# 3 de 105 <Response [200]> OK
# 4 de 105 <Response [200]> OK
# 5 de 105 <Response [200]> OK
# 6 de 105 <Response [200]> OK
# 7 de 105 <Response [200]> OK
# 8 de 105 <Response [200]> OK
# 9 de 105 <Response [200]> OK
# 10 de 105 <Response [200]> OK
# 11 de 105 <Response [200]> OK
# 12 de 105 <Response [200]> OK
# 13 de 105 <Response [200]> OK
# 14 de 105 <Response [200]> OK
# 15 de 105 <Response [200]> OK
# 16 de 105 <Response [200]> OK
# 17 de 105 <Response [200]> OK
# 18 de 105 <Response [200]> OK
# 19 de 105 <Response [200]> OK
# 20 de 105 <Response [200]> OK
# 21 de 105 <Response [200]> OK
# 22 de 105 <Response [200]> OK
# 23 de 105 <Response [200]> OK
# 24 de 105 <Response [200]> OK
# 25 de 105 <Response [200]> OK
# 26 de 105 <Response [200]> OK
# 27 de 105 <Response [200]> OK
# 28 de 105 <Response [200]> OK
# 29 de 105 <Response [200]> OK
# 30 de 105 <Response [200]> OK
# 31 de 105 <Response [200]> OK
# 32 de 105 <Response [200]> OK
# 33 de 105 <Response [200]> OK
# 34 de 105 <Response [200]> OK
# 35 de 105 <Response [200]> OK
# 36 de 105 <Response [200]> OK
# 37 de 105 <Response [200]> OK
# 38 de 105 <Response [200]> OK
# 39 de 105 <Response [200]> OK
# 40 de 105 <Response [200]> OK
# 41 de 105 <Response [200]> OK
# 42 de 105 <Response [200]> OK
# 43 de 105 <Response [200]> OK
# 44 de 105 <Response [200]> OK
# 45 de 105 <Response [200]> OK
# 46 de 105 <Response [200]> OK
# 47 de 105 <Response [200]> OK
# 48 de 105 <Response [200]> OK
# 49 de 105 <Response [200]> OK
# 50 de 105 <Response [200]> OK
# 51 de 105 <Response [200]> OK
# 52 de 105 <Response [200]> OK
# 53 de 105 <Response [200]> OK
# 54 de 105 <Response [200]> OK
# 55 de 105 <Response [200]> OK
# 56 de 105 <Response [200]> OK
# 57 de 105 <Response [200]> OK
# 58 de 105 <Response [200]> OK
# 59 de 105 <Response [200]> OK
# 60 de 105 <Response [200]> OK
# 61 de 105 <Response [200]> OK
# 62 de 105 <Response [200]> OK
# 63 de 105 <Response [200]> OK
# 64 de 105 <Response [200]> OK
# 65 de 105 <Response [200]> OK
# 66 de 105 <Response [200]> OK
# 67 de 105 <Response [200]> OK
# 68 de 105 <Response [200]> OK
# 69 de 105 <Response [200]> OK
# 70 de 105 <Response [200]> OK
# 71 de 105 <Response [200]> OK
# 72 de 105 <Response [200]> OK
# 73 de 105 <Response [200]> OK
# 74 de 105 <Response [200]> OK
# 75 de 105 <Response [200]> OK
# 76 de 105 <Response [200]> OK
# 77 de 105 <Response [200]> OK
# 78 de 105 <Response [200]> OK
# 79 de 105 <Response [200]> OK
# 80 de 105 <Response [200]> OK
# 81 de 105 <Response [200]> OK
# 82 de 105 <Response [200]> OK
# 83 de 105 <Response [200]> OK
# 84 de 105 <Response [200]> OK
# 85 de 105 <Response [200]> OK
# 86 de 105 <Response [200]> OK
# 87 de 105 <Response [200]> OK
# 88 de 105 <Response [200]> OK
# 89 de 105 <Response [200]> OK
# 90 de 105 <Response [200]> OK
# 91 de 105 <Response [200]> OK
# 92 de 105 <Response [200]> OK
# 93 de 105 <Response [200]> OK
# 94 de 105 <Response [200]> OK
# 95 de 105 <Response [200]> OK
# 96 de 105 <Response [200]> OK
# 97 de 105 <Response [200]> OK
# 98 de 105 <Response [200]> OK
# 99 de 105 <Response [200]> OK
# 100 de 105 <Response [200]> OK
# 101 de 105 <Response [200]> OK
# 102 de 105 <Response [200]> OK
# 103 de 105 <Response [200]> OK
# 104 de 105 <Response [200]> OK
