# %% [markdown]
# # <font color = 'Red'> Comparar Informacion entre conmutadores (Punto2 y Burro1)

# %%
import json,requests

# %% [markdown]
# ### <font color = 'Blue'> Autenticar

# %%
dir_punto_2='http://localhost:2002/pbxapi'
payload={'username':'admin', 'password':'cecomelastix'}
r=requests.post(dir_punto_2+'/authenticate', verify=False, data=payload)
token1=json.loads(r.text)
print(token1['access_token']+'\n')

dir_nuevo_conmutador='http://localhost:2212/pbxapi'
payload={'username':'admin', 'password':'c3c0mr3d35'}
r=requests.post(dir_nuevo_conmutador+'/authenticate', verify=False, data=payload)
token2=json.loads(r.text)
print(token2['access_token'])
# Out:
# eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpYXQiOjE2MTE3MzA2MDYsImV4cCI6MTYxMTczNDIwNiwiZGF0YSI6eyJuYW1lIjoiYWRtaW4ifX0.iUuYMoUNNqwX9i0cahlkPrd6JhjujqdvCNDiJ5upD94

# %% [markdown]
# ### <font color = 'Blue'> Troncales

# %%
##################################################### Script vs Conmutador ##########################################################
# with open ("Respaldo de Configuraciones/24-ene-21 sip2_burro_trunk", "r") as f:   # FILE: 24-ene-21 sip2_burro_trunk
#     f_contents=f.read()                                                           
# sip2_troncales_full=json.loads(f_contents)["results"]                             
################################################# Conmutador vs Conmutador ##########################################################
punto_2_trunk=requests.get(dir_punto_2+'/trunks',verify=False,headers={"Authorization":"Bearer"+token1['access_token']}) #Conmutador vs Conmutador
sip2_troncales_full=punto_2_trunk.json()["results"]                                                                     #Conmutador vs Conmutador
################################################ PRIMERO (Script/Conmutador) #######################################################################
sip2_troncales={""}
for troncal in sip2_troncales_full:
    sip2_troncales.add(troncal['trunk_name'])
print(sip2_troncales)
print()
######################################################### SEGUNDO #######################################################################
nuevo_conmutador_trunk=requests.get(dir_nuevo_conmutador+'/trunks', verify=False, headers= {"Authorization": "Bearer " + token2['access_token']})
burro_troncales_full=nuevo_conmutador_trunk.json()["results"]
nuevo_conmutador_trunk.json()
burro_troncales={""}
for troncal in burro_troncales_full:
    burro_troncales.add(troncal['channel_name'])
print(burro_troncales)
#print(json.dumps(nuevo_conmutador_trunk.json(), indent=2))
# Out:
# [{'id': '1', 'name': 'a_70_8', 'technology': 'sip', 'channel_name': 'A_70_8', 'patterns': [], 'peer': {'allow': 'g729', 'canreinvite': 'no', 'context': 'from-internal', 'disallow': 'all', 'dtmfmode': 'rfc2833', 'host': '10.201.70.8', 'insecure': 'very', 'nat': 'no', 'qualify': 'yes', 'secret': 'UCSc3c0m5DN', 'type': 'friend', 'username': 'UCSAplicacion'}, 'user': {'allow': 'g729', 'canreinvite': 'no', 'context': 'from-internal', 'disallow': 'all', 'dtmfmode': 'rfc2833', 'host': '10.201.70.8', 'insecure': 'very', 'nat': 'no', 'qualify': 'yes', 'secret': 'UCSc3c0m5DN', 'type': 'friend', 'user': 'UCSAplicacion', 'username': 'UCSAplicacion'}, 'register': ''}, {'id': '2', 'name': 'DN14', 'technology': 'sip', 'channel_name': 'A_SIP_DN14', 'patterns': [], 'peer': {'allow': 'g729', 'canreinvite': 'no', 'context': 'from-internal', 'disallow': 'all', 'dtmfmode': 'rfc2833', 'host': '10.7.169.5', 'insecure': 'invite', 'nat': 'no', 'qualify': 'yes', 'type': 'friend', 'username': 'admin'}, 'user':
# ...

# %%
# Out:
# {'', 'CME_CMI', 'a_SIP_CJR_I_RM', 'JFTAS_XIIRM', '3a_CINE', 'A_OAXACA', 'CENDI_3', 'a_2BPM', 'a_CJR_4a_ZM', 'A_34ZM', 'a_4_ELN_MANTO', 'CJR_VIIIRM', 'GN_PEDREGAL_SIP', 'HMR_XII_RM', 'a_CECOM', 'umce_tapachula', 'SEPTIMA', 'DIR_SVS', 'A_SIP3', 'A_70_8', 'CENDI_6', 'a_CME_3ZM', 'a_SIP5', '6_BPM', 'a_CJE_XII_RM_MPLS', 'CRI_IAX', 'A_PUNTO_4', 'a_CME_VILLAH', 'UMCE_40ZM', 'a_CIATRANS6', '27ZM_IAX2', 'UMCE_8ZM', 'a_CJR_3ZM', 'A_Ku', 'a_CJR_CD_JUAREZ', 'a_SIP_RASE', 'a_JEFATURAS', 'a_CG_43ZM', 'a_44zm', 'a_PSTN_CISCO', 'HMR_TORREON', 'HOSPITALMUJER', 'CME_JUZ_IIRM', 'A_4BGDA_PM_1', 'a_CJE_VI_RMMPLS', 'EMAAYS', '101_BI', 'a_SIP_ESG', 'CME_PENAS_ESCOBEDO', 'HMZ_1A', 'a_CIATRANS', 'A_70_9', 'HMR_35ZM', 'HMR_VIRM', 'a_CJR_V_RM_11_ZM', 'd_UMCE_PINOTEPA', 'GM_PIEDRASN', 'a_CJE_I_RM_2BPM', 'EMTEFA', '12RCM', 'cj_culiacan', 'GN_PEDREGAL_IAX', 'GM_LAZARO_C', 'a_CJR_42ZM', 'BAM11_EMATFA', 'HMR_MAZATLAN', 'a_CJR_10ZM', 'HMZ_SMJ', 'EME', 'A_cecom', 'a_IXTEPEC', 'a_BAM_18', 'a_SIP_UETAM', 'a_SIP_TRUNKIN
# ...

# %% [markdown]
# ### <font color = 'Blue'> Extensiones

# %%
##################################################### Script vs Conmutador ##########################################################
# with open ("Respaldo de Configuraciones/24-ene-21 sip2_burro_ext", "r") as f:   # FILE: 24-ene-21 sip2_burro_ext
#     f_contents=f.read()                                                           
# sip2_extensions_full=json.loads(f_contents)["results"]     
################################################# Conmutador vs Conmutador ##########################################################
punto_2_ext=requests.get(dir_punto_2+'/extensions', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
sip2_extensions_full=punto_2_ext.json()["results"]
################################################ PRIMERO (Script/Conmutador) ########################################################
sip2_ext={""}
for extension in sip2_extensions_full:
    sip2_ext.add(extension['extension'])
print(sip2_ext)  
print()
######################################################### SEGUNDO ###################################################################
nuevo_conmutador_ext=requests.get(dir_nuevo_conmutador+'/extensions', verify=False, headers= {"Authorization": "Bearer " + token2['access_token']})
burro_extensions_full=nuevo_conmutador_ext.json()["results"]
burro_ext={""}
for extension in burro_extensions_full:
    burro_ext.add(extension['extension'])
print(burro_ext)
# Out:
# {'', '1455', '1410', '1425', '1374', '8955', '1380', '1439', '6888', '6839', '6829', '6815', '6851', '1391', '6842', '1325', '1310', '1422', '6802', '1044', '1353', '1285', '6746', '1413', '1350', '6820', '6865', '8945', '1306', '1414', '8954', '1400', '1433', '6848', '1401', '1332', '1295', '6863', '6751', '6812', '6875', '8961', '6847', '1144', '1442', '1372', '6804', '8952', '1299', '6747', '1331', '1417', '6854', '6858', '1309', '1399', '6866', '1296', '1393', '6880', '1284', '2648', '6620', '1304', '8913', '6759', '8910', '1403', '6845', '1418', '6811', '1371', '1457', '1432', '1298', '1318', '1396', '6818', '6777', '1451', '1437', '1390', '1373', '6838', '1327', '1333', '1319', '8940', '6877', '1444', '6882', '1283', '6822', '1349', '1445', '1424', '6757', '6776', '6868', '1389', '6755', '1330', '6878', '6857', '1378', '8938', '1472', '8942', '6856', '8948', '8963', '6767', '6896', '6809', '6899', '1280', '1281', '6773', '1434', '6892', '1441', '1398', '6806', '1449', '1308', '
# ...

# %% [markdown]
# ### <font color = 'Blue'> Rutas

# %%
##################################################### Script vs Conmutador ##########################################################
# with open ("Respaldo de Configuraciones/24-ene-21 sip2_burro_out", "r") as f:   # FILE: 24-ene-21 sip2_burro_out
#     f_contents=f.read()                                                           
# sip2_rutas_full=json.loads(f_contents)["results"]     
################################################# Conmutador vs Conmutador ##########################################################
punto_2_out=requests.get(dir_punto_2+'/outboundroutes', verify=False, headers= {"Authorization": "Bearer " + token1['access_token']})
sip2_rutas_full=punto_2_out.json()['results']
################################################ PRIMERO (Script/Conmutador) ########################################################
sip2_rutas={""}
for ruta in sip2_rutas_full:
    sip2_rutas.add(ruta['name'])
print(sip2_rutas)  
print()
######################################################### SEGUNDO ###################################################################
nuevo_conmutador_out=requests.get(dir_nuevo_conmutador+'/outboundroutes', verify=False, headers= {"Authorization": "Bearer " + token2['access_token']})
burro_rutas_full=nuevo_conmutador_out.json()['results']
burro_rutas={""}
for ruta in burro_rutas_full:
    burro_rutas.add(ruta['name'])
print(burro_rutas)
# Out:
# {'', 'A_CIATRANS', 'CJM_IX_RM_CHILPA', 'CPO_FZAS_ESP', 'GAIN', 'SIP3', '82BI_Y_GM_LAZAR_C', 'DN14', 'JEFATURAS_XIIRM', 'CJE_VI_RM_MPLS', '7_BIC', '70BI_XICOTEPEC', 'A_HMR_MAZATLAN', 'CJE_XII_RM_MPLS', 'CJR_5ZM', 'cj_33_ZONA_M', 'HCOLMIL_NUEVO', 'ESC_SUP_GRRA', '44_Z_M', 'HMR_XIIRM', 'BAM_11_EMATFA', 'GN_TORRE_PEDREGAL', '4_BGDA_PM', '6_BgdaPM', 'GM_PIEDRASN', 'CJ_MORELIA', 'JFA_SVS_IV_RM', 'HOSP_24_ZM', 'CENDI_6', '2a_BPM', 'CMI', 'CJR_3a_ZM', 'HMR_VII_RM', 'HMEMN', 'CJR_VIRM_6RBR', 'CJR_GN_JUAREZ', '5BIC', 'HMR_TORREON', 'CJE_VRM_SEII', 'HOSP_25ZM', 'BLT_CIA_MANTO', 'CJE_XIRM', 'HOSP_35_ZM', 'CJR_8ZM', '79_BI_TECALITLAN', 'EMAAYS', 'CJR_42ZM', 'CJR_10ZM', 'CJR_IXRM', 'CIAM', 'UMCE_TAPACHULA', 'CJR_4a_ZM', '4oELN_MNTO_IRM', 'JEFATURAS_VIII_RM', 'TRONCALIZADO', 'HMZ_1A', 'HOSP_CTRL_MIL', 'BAM_18', 'CENDI_4', 'MEXSAT_DIAL_PLAN', 'HMZ_CHEM', 'UETA', 'EMTEFA', '7_ZM', 'RASE', 'CG_27ZM', 'CJ_CULIACAN', 'CJR_I_RM', 'CJR_VICTORIA', '12RCM_PIED_NEG', 'CRI', 'CMG_STA_GERT', 'CJ_IXTEPEC', '108
# ...

# %% [markdown]
# ### <font color = 'Blue'> Comparar Configuraciones

# %%
 sip2_ext-burro_ext
# Out:
# {'1044', '1045', '1352', '1353', '1354', '1355'}

# %%
 sip2_rutas-burro_rutas
# Out:
# {'HCOLMIL_NUEVO', 'HMZ_CHEM'}

# %%
sip2_troncales-burro_troncales
# Out:
# {'HCOLMIL_NUEVO', 'HMZ_CHEM'}
